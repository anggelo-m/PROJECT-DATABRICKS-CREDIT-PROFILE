# %%
# %python
dbutils.widgets.removeAll()

# %%
# %sql
create widget text storageName default "adlssmartdata1202";

# %% [markdown]
# CREATION CATALOG AND SCHEMA BRONZE, SILVER, GOLDEN

# %%
# %sql
CREATE CATALOG IF NOT EXISTS credit_catalog

# %%
# %sql
USE CATALOG credit_catalog

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS credit_catalog.bronze;
CREATE SCHEMA IF NOT EXISTS credit_catalog.silver;
CREATE SCHEMA IF NOT EXISTS credit_catalog.golden;

# %% [markdown]
# EXTERNAL LOCATION

# %% [markdown]
# RAW

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS `exlt-raw`
URL 'abfss://raw@${storageName}.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL credential)
COMMENT 'Ubicación de csv en raw';

# %% [markdown]
# BRONZE

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS `exlt-bronze`
URL 'abfss://bronze@${storageName}.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL credential)
COMMENT 'Ubicación para tablas en bronze';

# %% [markdown]
# SILVER

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS `exlt-silver`
URL 'abfss://silver@${storageName}.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL credential)
COMMENT 'Ubicación para tablas en silver';

# %% [markdown]
# GOLDEN

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS `exlt-golden`
URL 'abfss://golden@${storageName}.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL credential)
COMMENT 'Ubicación para tablas en golden';
