-- %% [markdown]
-- Delta Sharing for Power Bi Connection

-- %%
%sql
select * from credit_catalog.golden.golden_customer_credit_profile

-- %%
%sql
CREATE SHARE IF NOT EXISTS CUSTOMER_CREDIT_PROFILE_SHARE;

-- %%
%sql
SHOW SHARES

-- %%
%sql
ALTER SHARE CUSTOMER_CREDIT_PROFILE_SHARE 
ADD TABLE credit_catalog.golden.golden_customer_credit_profile
WITH HISTORY

-- %%
%sql
CREATE RECIPIENT IF NOT EXISTS ExternalCompanys;

-- %%
%sql
GRANT SELECT 
ON SHARE CUSTOMER_CREDIT_PROFILE_SHARE
TO RECIPIENT ExternalCompanys
